# %% [markdown]
# # Experimenting with ResNet50

# %%
# Imports modules, dataset and results paths
from modules.paths import (
    TESTING_DATASET,
    TRAINING_DATASET,
)
from models.trainer import (
    build_model,
    run_experiment,
)
from models.metrics import display_results, load_results
from models.plots import plot_history

# %%
# Running ResNet50 Experiment with Data Augmentation and Normalization & Batch 16
resnet_results = run_experiment(
    name="resnet50",
    model_builder=lambda: build_model("resnet50"),
    train_dir=TRAINING_DATASET,
    val_dir=TESTING_DATASET,
    test_dir=TESTING_DATASET,
    image_size=224,
    batch_size=32,
    epochs=60,
    lr=5e-4,
    augment=True,
    normalize=True,
)

# %%
# Loading results from JSON file
resnet50_json_results = load_results("resnet50-b32-img224-e60-lr-1e-3.json")

# Displaying results if available in results as JSON file
display_results("ResNet50 (saved)", resnet50_json_results)
# Out:
# ResNet50 (saved) - Best epoch: 30/60 (validation: 0.9292)
# Final validation: 0.9292 | Test: 0.9292
# Parameters: image_size=224, batch_size=32, lr=0.001, augment=True, normalize=True
# Checkpoint: /Users/vincent/Projects/Arc/models/checkpoints/resnet50-b32-img224-e60-lr-1e-3.pt

# %%
# Displaying learning and validation curves if available in notebook variables and outputs
plot_history(
    resnet50_json_results["history"],
    "ResNet50 Training and Validation Accuracy from JSON Results",
)
